# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
crime_data = pd.read_csv('datasets/Crime head-wise persons arrested under crime against children during 2001-2012.csv')

# %%
crime_data.head(10)
# Out:
#             STATE/UT   CRIME HEAD  2001  2002  2003  2004  2005  2006  2007  \
# 0     ANDHRA PRADESH  INFANTICIDE     1     1     3     0     0     0     1
# 1  ARUNACHAL PRADESH  INFANTICIDE     0     0     0     0     0     0     0
# 2              ASSAM  INFANTICIDE     0     5     0     0     1     0     0
# 3              BIHAR  INFANTICIDE     0     0     0     0     2     0     2
# 4       CHHATTISGARH  INFANTICIDE     7    29     5    12     0    15    11
# 5                GOA  INFANTICIDE     0     0     0     0     0     1     0
# 6            GUJARAT  INFANTICIDE     2     0     0     1     6     0     7
# 7            HARYANA  INFANTICIDE     0     3     0     1     0     0     1
# 8   HIMACHAL PRADESH  INFANTICIDE     0     0     3     0     0     0     0
# 9    JAMMU & KASHMIR  INFANTICIDE     0     0     0     0     0     0     0
#
#    2008  2009  2010  2011  2012
# 0     0     5     6     1     6
# 1     0     0     0     0     0
# 2     0     0     0     0     0
# ...

# %%
crime_data.set_index(['STATE/UT', 'CRIME HEAD'], inplace=True)
crime_data.sort_index(inplace=True)

# %%
crime_data
# Out:
#                                                         2001  2002  2003  \
# STATE/UT          CRIME HEAD
# A & N ISLANDS      TOTAL CRIMES AGAINST CHILDREN           0     0     4
#                   ABETMENT OF SUICIDE                      0     0     0
#                   BUYING OF GIRLS FOR PROSTITUTION         0     0     0
#                   EXPOSURE AND ABANDONMENT                 0     0     0
#                   FOETICIDE                                0     0     0
#                   INFANTICIDE                              0     0     0
#                   KIDNAPPING and ABDUCTION OF CHILDREN     0     0     1
#                   MURDER OF CHILDREN                       0     0     1
#                   OTHER CRIMES AGAINST CHILDREN            0     0     0
#                   PROCURATION OF MINOR GILRS               0     0     0
#                   PROHIBITION OF CHILD MARRIAGE ACT        0     0     0
# ...

# %%
crime_data.to_csv('datasets/crime-against-children-person-arrested-2001-2012-new.csv')

# %%
# more processing data
crime_data_2 = pd.read_csv('datasets/crime-against-children-person-arrested-2001-2012-new.csv', skipinitialspace=True, index_col=[0,1])

# %%
crime_data_2.head(10)
# Out:
#                                                     2001  2002  2003  2004  \
# STATE/UT      CRIME HEAD
# A & N ISLANDS TOTAL CRIMES AGAINST CHILDREN            0     0     4    20
#               ABETMENT OF SUICIDE                      0     0     0     0
#               BUYING OF GIRLS FOR PROSTITUTION         0     0     0     0
#               EXPOSURE AND ABANDONMENT                 0     0     0     0
#               FOETICIDE                                0     0     0     0
#               INFANTICIDE                              0     0     0     0
#               KIDNAPPING and ABDUCTION OF CHILDREN     0     0     1     0
#               MURDER OF CHILDREN                       0     0     1     0
#               OTHER CRIMES AGAINST CHILDREN            0     0     0    13
#               PROCURATION OF MINOR GILRS               0     0     0     0
#
#                                                     2005  2006  2007  2008  \
# STATE/UT      CRIME HEAD
# ...

# %%
crime_data_2.loc['GOA', :].T
# Out:
# CRIME HEAD  TOTAL CRIMES AGAINST CHILDREN  ABETMENT OF SUICIDE  \
# 2001                                   35                    0
# 2002                                   35                    0
# 2003                                   56                    0
# 2004                                   64                    0
# 2005                                   76                    0
# 2006                                   69                    0
# 2007                                   71                    0
# 2008                                  104                    4
# 2009                                  123                    0
# 2010                                   80                    0
# 2011                                   70                    0
# 2012                                  125                    1
#
# CRIME HEAD  BUYING OF GIRLS FOR PROSTITUTION  EXPOSURE AND ABANDONMENT  \
# 2001                                       0                         1
# ...

# %%
STATES = ['ANDHRA PRADESH','ARUNACHAL PRADESH','ASSAM','BIHAR','GOA',
 'GUJARAT' ,'HARYANA' ,'HIMACHAL PRADESH', 'JAMMU & KASHMIR',
 'KARNATAKA', 'KERALA', 'MADHYA PRADESH', 'MAHARASHTRA', 'MANIPUR', 'MEGHALAYA',
 'MIZORAM', 'NAGALAND', 'ODISHA', 'PUNJAB', 'RAJASTHAN', 'SIKKIM', 'TAMIL NADU',
 'TRIPURA', 'UTTAR PRADESH', 'UTTARAKHAND', 'WEST BENGAL','CHHATTISGARH', 'JHARKHAND']

# %%
UTS = ['A & N ISLANDS', 'CHANDIGARH', 'D & N HAVELI', 'DAMAN & DIU', 'DELHI'
 ,'LAKSHADWEEP', 'PUDUCHERRY']

# %%
all_region =pd.Series([crime_data_2.index.values[i][0] for i in range(crime_data_2.index.values.shape[0])]).unique()

# %%
all_region
# Out:
# array(['A & N ISLANDS', 'ANDHRA PRADESH', 'ARUNACHAL PRADESH', 'ASSAM',
#        'BIHAR', 'CHANDIGARH', 'CHHATTISGARH', 'D & N HAVELI',
#        'DAMAN & DIU', 'DELHI', 'GOA', 'GUJARAT', 'HARYANA',
#        'HIMACHAL PRADESH', 'JAMMU & KASHMIR', 'JHARKHAND', 'KARNATAKA',
#        'KERALA', 'LAKSHADWEEP', 'MADHYA PRADESH', 'MAHARASHTRA',
#        'MANIPUR', 'MEGHALAYA', 'MIZORAM', 'NAGALAND', 'ODISHA',
#        'PUDUCHERRY', 'PUNJAB', 'RAJASTHAN', 'SIKKIM', 'TAMIL NADU',
#        'TOTAL (ALL-INDIA)', 'TOTAL (STATES)', 'TOTAL (UTs)', 'TRIPURA',
#        'UTTAR PRADESH', 'UTTARAKHAND', 'WEST BENGAL'], dtype=object)

# %%
crime_data_new_2 = pd.DataFrame(columns=np.array(crime_data_2.loc['GOA'].T.columns))

# %%
crime_data_2.loc['GOA', :].T
# Out:
# CRIME HEAD  TOTAL CRIMES AGAINST CHILDREN  ABETMENT OF SUICIDE  \
# 2001                                   35                    0
# 2002                                   35                    0
# 2003                                   56                    0
# 2004                                   64                    0
# 2005                                   76                    0
# 2006                                   69                    0
# 2007                                   71                    0
# 2008                                  104                    4
# 2009                                  123                    0
# 2010                                   80                    0
# 2011                                   70                    0
# 2012                                  125                    1
#
# CRIME HEAD  BUYING OF GIRLS FOR PROSTITUTION  EXPOSURE AND ABANDONMENT  \
# 2001                                       0                         1
# ...

# %%
reg = 'GOA'

# %%
for reg in all_region:
    crime_data_new_2 = pd.concat([crime_data_new_2, crime_data_2.loc[reg, :].T])

# %%
crime_data_new_2
# Out:
# CRIME HEAD TOTAL CRIMES AGAINST CHILDREN ABETMENT OF SUICIDE  \
# 2001                                   0                   0
# 2002                                   0                   0
# 2003                                   4                   0
# 2004                                  20                   0
# 2005                                  17                   0
# 2006                                  10                   0
# 2007                                   9                   0
# 2008                                  52                   0
# 2009                                  63                   0
# 2010                                  61                   0
# 2011                                  36                   0
# 2012                                  33                   0
# 2001                                 294                   7
# 2002                                 400                  15
# ...
